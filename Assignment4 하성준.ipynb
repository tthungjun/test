# %% [markdown]
# **<span style="color:#ffdce0">D.Com 2023 신입생 파이썬 스터디</span>**
#
# **세번째 과제**
#
# **과제 풀이 방법:**
# 각 문제 아래 위치한 셀에 코드를 작성하고
# "Shift" + "Enter" 를 눌러 셀을 실행시켜 조건에 따른 올바른 결과가 나오도록 합니다.
#
# **과제 제출 기한:**
# 다음 수업 전까지 "신정안"에게 카카오톡으로 과제 제출해주시면 됩니다.
#
# **과제 제출 유의사항:**
# 파일 이름을  "**Assignment4_홍길동**" 과 같이 뒤에 이름을 붙여 바꿔주신 후 제출해주시면 됩니다.

# %% [markdown]
# **<span style="color:#ffdce0">문제 1번</span>**
#
# 이름, 나이, 학과를 받아 각각 출력하시오.</br>
# 변수 이름(name, age, major) 사용.</br>
# </br>
# 입력 형식:</br>
# 홍길동</br>
# 23</br>
# 컴퓨터공학과</br>
# </br>
# 출력 형식:</br>
# 홍길동 23 컴퓨터공학과</br>

# %%
#문제 1번

name = "하성준"
age ="23"
major = "컴퓨터공학과"
print(name, age, major)
# Out:
# 하성준 23 컴퓨터공학과

# %% [markdown]
# **<span style="color:#ffdce0">문제 2번</span>**
#
# 시간, 분, 초를 아래의 입력 형식과 같이 각각 입력 받아 저장하고, 출력 형식에 맞게 현재 시각을 출력하라</br>
# </br>
# 입력 형식:</br>
# 14</br>
# 30</br>
# 49</br>
# </br>
# 출력 형식:</br>
# 현재 시각은 14시 30분 49초 입니다.</br>

# %%
#문제 2번

hour = " 14"
minute = " 30"
sec = " 49"
print("현재 시각은" + hour + "시" + minute + "분" +sec+ "초 입니다")
# Out:
# 현재 시각은 14시 30분 49초 입니다

# %% [markdown]
# 3030**<span style="color:#ffdce0">문제 3번</span>**
#
# 슬라이싱과 문자열 합치기를 이용해 날짜 형식을 바꾸어 주세요.</br>
# </br>
# 입력 형식:</br>
# 20230316</br>
# </br>
# 출력 형식:</br>
# 2023-03-16</br>

# %%
#문제 3번

a = "2023"
b = "03"
c = "16"
a = a. replace("2023", "2023-")
b = b. replace("03", "03-")
print(a + b + c)
# Out:
# 2023-03-16

# %% [markdown]
# **<span style="color:#ffdce0">문제 4번</span>**
#
# 두 수를 input으로 받은 후 add라는 함수를 만들어 두 수를 더하는 프로그램을 작성하시오.</br>
# (add함수는 2개의 정수형 인자와 1개의 리턴 값을 가지고 있습니다.)</br>
# </br>
# 입력 형식:</br>
# 10</br>
# 20</br>
# </br>
# 출력 형식:</br>
# 30</br>

# %%
#문제 4번
def func(a, b):
    sum = a + b
    return sum
a = int(input())
b = int(input())
print(a)
print(b)
print(func(a, b))
# Out:
# 10
# 20
# 30
